# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavani12860/Fmml-labs/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-14 05:25:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   215MB/s    in 0.3s
#
# 2025-03-14 05:25:06 (215 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 16  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 13042   1311.4643v1  We consider the problem of selecting non-zero ...    cs
# 22877  1709.09301v1  We propose a Bayesian regression method that a...  stat
# 8978   1802.07997v1  We address the task of generating query sugges...    cs
# 35742   1203.0436v2  Continuous logic extends the multi-valued Luka...    cs
# 4294   1707.07493v1  List-wise learning to rank methods are conside...    cs
# ...             ...                                                ...   ...
# 4365   1606.01284v1  Driving styles have a great influence on vehic...  stat
# 31652  1803.08414v1  In this paper, we adapt the Faster-RCNN framew...    cs
# 20218  1504.05846v2  Constraint programming is a family of techniqu...    cs
# 9729   1712.07436v2  Continuous appearance shifts such as changes i...  stat
# 22671  1704.00541v2  To ensure interpretability of extracted source...  stat
#
#                                                    title  year keywords
# 13042  Near-Optimal Entrywise Sampling for Data Matrices  2013       []
# 22877  Multi-way Interacting Regression via Factoriza...  2017       []
# 8978   Generating High-Quality Query Suggestion Candi...  2018       []
# 35742                   (Dual) Hoops Have Unique Halving  2012       []
# 4294   Modeling Label Ambiguity for Neural List-Wise ...  2017       []
# ...                                                  ...   ...      ...
# 4365   Statistical Pattern Recognition for Driving St...  2016       []
# 31652  Buried object detection from B-scan ground pen...  2018       []
# 20218  Generalized Support and Formal Development of ...  2015       []
# 9729   Incremental Adversarial Domain Adaptation for ...  2017       []
# 22671  Dictionary-based Tensor Canonical Polyadic Dec...  2017       []
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 13042                               []
# 22877                               []
# 8978                                []
# 35742                               []
# 4294                                []
#                      ...
# 13210                               []
# 29009    [httpsgithubcomtyshiwomemnet]
# 31166                               []
# 22764                               []
# 23098                               []
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 312 words.
# Out of those 41 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="73043240-28e8-478b-a2f9-0398975839d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73043240-28e8-478b-a2f9-0398975839d0")) {                    Plotly.newPlot(                        "73043240-28e8-478b-a2f9-0398975839d0",                        [{"x":["reparameterization","complementarities","distinguishability","reparameterizations","reparametrizations","misclassification","histopathological","interdependencies","directedundirected","interchangeability","neurodegeneration","electroencephalogram","probabilistically","characterizations","straightforwardly","interdisciplinary","explorationexploitation","unidentifiability","nonparametrically","switchboardcallhome","indistinguishable","generativediscriminative","electrocardiogram","neurodegenerative","electromechanical","deterministically","magnetoencephalographic","parameterizations","electrophysiological","eigendecomposition","differentiability","eigendecompositions","pharmacovigilance","interrelationship","reparametrization","parallelizability","misclassifications","foregroundbackground","disproportionately","multidisciplinary","selectorecombinative"],"y":[1,2,1,0,0,7,4,2,1,3,2,2,6,6,4,2,1,1,1,2,5,2,3,2,1,2,0,3,1,0,2,1,2,1,0,1,1,2,1,1,2],"type":"bar"},{"x":["reparameterization","complementarities","distinguishability","reparameterizations","reparametrizations","misclassification","histopathological","interdependencies","directedundirected","interchangeability","neurodegeneration","electroencephalogram","probabilistically","characterizations","straightforwardly","interdisciplinary","explorationexploitation","unidentifiability","nonparametrically","switchboardcallhome","indistinguishable","generativediscriminative","electrocardiogram","neurodegenerative","electromechanical","deterministically","magnetoencephalographic","parameterizations","electrophysiological","eigendecomposition","differentiability","eigendecompositions","pharmacovigilance","interrelationship","reparametrization","parallelizability","misclassifications","foregroundbackground","disproportionately","multidisciplinary","selectorecombinative"],"y":[4,0,3,2,2,10,0,1,1,0,0,0,2,6,4,2,1,1,2,0,3,0,2,0,1,3,2,2,1,4,4,1,0,1,2,1,2,0,1,1,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5 ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (41,), (41, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.425

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Kernel</span> <span style=''>Pitman</span> <span style=''>Yor</span> <span style=''>Process</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>Pitman</span> <span style=''>Yor</span> <span style=''>process</span> <span style=''>(KPYP)</span> <span style=''>for</span> <span style=''>nonparametric</span> <span style=''>clustering</span> <span style=''>of</span> <span style=''>data</span> <span style=''>with</span> <span style=''>general</span> <span style=''>spatial</span> <span style=''>or</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>interdependencies</span> <span style=''>The</span> <span style=''>KPYP</span> <span style=''>is</span> <span style=''>constructed</span> <span style=''>by</span> <span style=''>first</span> <span style=''>introducing</span> <span style=''>an</span> <span style=''>infinite</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>random</span> <span style=''>locations</span> <span style=''>Then</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>stick</span> <span style=''>breaking</span> <span style=''>construction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Pitman</span> <span style=''>Yor</span> <span style=''>process</span> <span style=''>we</span> <span style=''>define</span> <span style=''>a</span> <span style=''>predictor</span> <span style=''>dependent</span> <span style=''>random</span> <span style=''>probability</span> <span style=''>measure</span> <span style=''>by</span> <span style=''>considering</span> <span style=''>that</span> <span style=''>the</span> <span style=''>discount</span> <span style=''>hyperparameters</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Beta</span> <span style=''>distributed</span> <span style=''>random</span> <span style=''>weights</span> <span style=''>(stick</span> <span style=''>variables)</span> <span style=''>of</span> <span style=''>the</span> <span style=''>process</span> <span style=''>are</span> <span style=''>not</span> <span style=''>uniform</span> <span style=''>among</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>but</span> <span style=''>controlled</span> <span style=''>by</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>expressing</span> <span style=''>the</span> <span style=''>proximity</span> <span style=''>between</span> <span style=''>the</span> <span style=''>location</span> <span style=''>assigned</span> <span style=''>to</span> <span style=''>each</span> <span style=''>weight</span> <span style=''>and</span> <span style=''>the</span> <span style=''>given</span> <span style=''>predictors</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Reinforcement</span> <span style=''>Learning</span> <span style=''>Algorithm</span> <span style=''>Selection</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>formalises</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>online</span> <span style=''>algorithm</span> <span style=''>selection</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>Reinforcement</span> <span style=''>Learning</span> <span style=''>The</span> <span style=''>setup</span> <span style=''>is</span> <span style=''>as</span> <span style=''>follows</span> <span style=''>given</span> <span style=''>an</span> <span style=''>episodic</span> <span style=''>task</span> <span style=''>and</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>number</span> <span style=''>of</span> <span style=''>off</span> <span style=''>policy</span> <span style=''>RL</span> <span style=''>algorithms</span> <span style=''>a</span> <span style=''>meta</span> <span style=''>algorithm</span> <span style=''>has</span> <span style=''>to</span> <span style=''>decide</span> <span style=''>which</span> <span style=''>RL</span> <span style=''>algorithm</span> <span style=''>is</span> <span style=''>in</span> <span style=''>control</span> <span style=''>during</span> <span style=''>the</span> <span style=''>next</span> <span style=''>episode</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>maximize</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>return</span> <span style=''>The</span> <span style=''>article</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>meta</span> <span style=''>algorithm</span> <span style=''>called</span> <span style=''>Epochal</span> <span style=''>Stochastic</span> <span style=''>Bandit</span> <span style=''>Algorithm</span> <span style=''>Selection</span> <span style=''>(ESBAS)</span> <span style=''>Its</span> <span style=''>principle</span> <span style=''>is</span> <span style=''>to</span> <span style=''>freeze</span> <span style=''>the</span> <span style=''>policy</span> <span style=''>updates</span> <span style=''>at</span> <span style=''>each</span> <span style=''>epoch</span> <span style=''>and</span> <span style=''>to</span> <span style=''>leave</span> <span style=''>a</span> <span style=''>rebooted</span> <span style=''>stochastic</span> <span style=''>bandit</span> <span style=''>in</span> <span style=''>charge</span> <span style=''>of</span> <span style=''>the</span> <span style=''>algorithm</span> <span style=''>selection</span> <span style=''>Under</span> <span style=''>some</span> <span style=''>assumptions</span> <span style=''>a</span> <span style=''>thorough</span> <span style=''>theoretical</span> <span style=''>analysis</span> <span style=''>demonstrates</span> <span style=''>its</span> <span style=''>near</span> <span style=''>optimality</span> <span style=''>considering</span> <span style=''>the</span> <span style=''>structural</span> <span style=''>sampling</span> <span style=''>budget</span> <span style=''>limitations</span> <span style=''>ESBAS</span> <span style=''>is</span> <span style=''>first</span> <span style=''>empirically</span> <span style=''>evaluated</span> <span style=''>on</span> <span style=''>a</span> <span style=''>dialogue</span> <span style=''>task</span> <span style=''>where</span> <span style=''>it</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>outperform</span> <span style=''>each</span> <span style=''>individual</span> <span style=''>algorithm</span> <span style=''>in</span> <span style=''>most</span> <span style=''>configurations</span> <span style=''>ESBAS</span> <span style=''>is</span> <span style=''>then</span> <span style=''>adapted</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Probabilistic</span> <span style=''>Interpretations</span> <span style=''>for</span> <span style=''>MYCINs</span> <span style=''>Certainty</span> <span style=''>Factors</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>examines</span> <span style=''>the</span> <span style=''>quantities</span> <span style=''>used</span> <span style=''>by</span> <span style=''>MYCIN</span> <span style=''>to</span> <span style=''>reason</span> <span style=''>with</span> <span style=''>uncertainty</span> <span style=''>called</span> <span style=''>certainty</span> <span style=''>factors</span> <span style=''>It</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style=''>original</span> <span style=''>definition</span> <span style=''>of</span> <span style=''>certainty</span> <span style=''>factors</span> <span style=''>is</span> <span style=''>inconsistent</span> <span style=''>with</span> <span style=''>the</span> <span style=''>functions</span> <span style=''>used</span> <span style=''>in</span> <span style=''>MYCIN</span> <span style=''>to</span> <span style=''>combine</span> <span style=''>the</span> <span style=''>quantities</span> <span style=''>This</span> <span style=''>inconsistency</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>argue</span> <span style=''>for</span> <span style=''>a</span> <span style=''>redefinition</span> <span style=''>of</span> <span style=''>certainty</span> <span style=''>factors</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style=''>intuitively</span> <span style=''>appealing</span> <span style=''>desiderata</span> <span style=''>associated</span> <span style=''>with</span> <span style=''>the</span> <span style=''>combining</span> <span style=''>functions</span> <span style=''>It</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>this</span> <span style=''>redefinition</span> <span style=''>accommodates</span> <span style=''>an</span> <span style=''>unlimited</span> <span style=''>number</span> <span style=''>of</span> <span style=''>probabilistic</span> <span style=''>interpretations</span> <span style=''>These</span> <span style=''>interpretations</span> <span style=''>are</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style=''>monotonic</span> <span style=''>transformations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>likelihood</span> <span style=''>ratio</span> <span style=''>p(EIH)p(El</span> <span style=''>H)</span> <span style=''>The</span> <span style=''>construction</span> <span style=''>of</span> <span style=''>these</span> <span style=''>interpretations</span> <span style=''>provides</span> <span style=''>insight</span> <span style=''>into</span> <span style=''>the</span> <span style=''>assumptions</span> <span style=''>implicit</span> <span style=''>in</span> <span style=''>the</span> <span style=''>certainty</span> <span style=''>factor</span> <span style=''>model</span> <span style=''>In</span> <span style=''>particular</span> <span style=''>it</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>if</span> <span style=''>uncertainty</span> <span style=''>is</span> <span style=''>to</span> <span style=''>be</span> <span style=''>propagated</span> <span style=''>through</span> <span style=''>an</span> <span style=''>inference</span> <span style=''>network</span> <span style=''>in</span> <span style=''>accordance</span> <span style=''>with</span> <span style=''>the</span> <span style=''>desiderata</span> <span style=''>evidence</span> <span style=''>must</span> <span style=''>be</span> <span style=''>conditionally</span> <span style=''>independent</span> <span style=''>given</span> <span style='' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	pharmacovigilance (0.0007137758743754461)
# 	electroencephalogram (0.0007137758743754461)
# 	neurodegeneration (0.0007137758743754461)
# 	foregroundbackground (0.0007137758743754461)
# 	complementarities (0.0007137758743754461)
# 	neurodegenerative (0.0007137758743754461)
# 	selectorecombinative (0.0007137758743754461)
# 	interchangeability (0.0010706638115631692)
# 	probabilistically (0.0021413276231263384)
# 	histopathological (0.0014275517487508922)
#
# Some Statistics words are:
# 	characterizations (0.003003003003003003)
# 	reparametrization (0.001001001001001001)
# 	magnetoencephalographic (0.001001001001001001)
# 	reparametrizations (0.001001001001001001)
# 	reparameterizations (0.001001001001001001)
# 	distinguishability (0.0015015015015015015)
# 	differentiability (0.002002002002002002)
# 	reparameterization (0.002002002002002002)
# 	eigendecomposition (0.002002002002002002)
# 	misclassification (0.005005005005005005)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0c805757-d535-4076-90e8-93cd4909ad1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c805757-d535-4076-90e8-93cd4909ad1e")) {                    Plotly.newPlot(                        "0c805757-d535-4076-90e8-93cd4909ad1e",                        [{"x":["reparameterization","complementarities","distinguishability","reparameterizations","reparametrizations","misclassification","histopathological","interdependencies","directedundirected","interchangeability","neurodegeneration","electroencephalogram","probabilistically","characterizations","straightforwardly","interdisciplinary","explorationexploitation","unidentifiability","nonparametrically","switchboardcallhome","indistinguishable","generativediscriminative","electrocardiogram","neurodegenerative","electromechanical","deterministically","magnetoencephalographic","parameterizations","electrophysiological","eigendecomposition","differentiability","eigendecompositions","pharmacovigilance","interrelationship","reparametrization","parallelizability","misclassifications","foregroundbackground","disproportionately","multidisciplinary","selectorecombinative"],"y":[0.00035688793718772306,0.0007137758743754461,0.00035688793718772306,0.0,0.0,0.0024982155603140615,0.0014275517487508922,0.0007137758743754461,0.00035688793718772306,0.0010706638115631692,0.0007137758743754461,0.0007137758743754461,0.0021413276231263384,0.0021413276231263384,0.0014275517487508922,0.0007137758743754461,0.00035688793718772306,0.00035688793718772306,0.00035688793718772306,0.0007137758743754461],"type":"bar"},{"x":["reparameterization","complementarities","distinguishability","reparameterizations","reparametrizations","misclassification","histopathological","interdependencies","directedundirected","interchangeability","neurodegeneration","electroencephalogram","probabilistically","characterizations","straightforwardly","interdisciplinary","explorationexploitation","unidentifiability","nonparametrically","switchboardcallhome","indistinguishable","generativediscriminative","electrocardiogram","neurodegenerative","electromechanical","deterministically","magnetoencephalographic","parameterizations","electrophysiological","eigendecomposition","differentiability","eigendecompositions","pharmacovigilance","interrelationship","reparametrization","parallelizability","misclassifications","foregroundbackground","disproportionately","multidisciplinary","selectorecombinative"],"y":[0.2,0.9999999999999999,0.24999999999999997,0.0,0.0,0.411764705882353,0.9999999999999999,0.6666666666666666,0.49999999999999994,1.0,0.9999999999999999,0.9999999999999999,0.75,0.5,0.49999999999999994,0.49999999999999994,0.49999999999999994,0.49999999999999994,0.3333333333333333,0.9999999999999999],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0, ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	reparameterizations
# 	reparametrizations
# 	magnetoencephalographic
# 	eigendecomposition
# 	reparametrization
# Some words which never appear in Statistics papers:
# 	complementarities
# 	histopathological
# 	interchangeability
# 	neurodegeneration
# 	electroencephalogram
# 	switchboardcallhome
# 	generativediscriminative
# 	neurodegenerative
# 	pharmacovigilance
# 	foregroundbackground
# 	selectorecombinative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.563664872955348e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.4241666666666667
